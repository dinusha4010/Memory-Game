# %% [markdown]
# <a href="https://colab.research.google.com/github/dinusha4010/Memory-Game/blob/main/project_works_Miracle_workers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
hr_dataframe=pd.read_csv("/content/sample_data/HR_dataset.csv")
hr_dataframe.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# ...

# %%
hr_dataframe.columns
hr_dataframe.shape
df1=hr_dataframe[['number_project','Department','time_spend_company']]
df1.head(10)
# Out:
#    number_project Department  time_spend_company
# 0               2      sales                   3
# 1               5      sales                   6
# 2               7      sales                   4
# 3               5      sales                   5
# 4               2      sales                   3
# 5               2      sales                   3
# 6               6      sales                   4
# 7               5      sales                   5
# 8               5      sales                   5
# 9               2      sales                   3

# %%
df2=df1[(df1['number_project']>=5)]
df2.head(10)
# Out:
#     number_project Department  time_spend_company
# 1                5      sales                   6
# 2                7      sales                   4
# 3                5      sales                   5
# 6                6      sales                   4
# 7                5      sales                   5
# 8                5      sales                   5
# 11               6      sales                   4
# 19               5      sales                   5
# 20               6      sales                   4
# 22               6      sales                   4

# %%
sample1=df1.sample(5)
sample1
# Out:
#        number_project Department  time_spend_company
# 4216                3      sales                   5
# 6734                3      sales                   3
# 2612                5      sales                   5
# 6837                5  technical                   2
# 14947               4    support                   6

# %%
hr_dataframe.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                    object
# dtype: object
